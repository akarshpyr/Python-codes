# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshpyr/Python-codes/blob/main/EDApractice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/data_clean.csv')

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
df.dropna(inplace=True)

# %%
df['Ozone'].hist()
data_box = df.dropna()
data1_box = data_box.Ozone

# %%
plt.boxplot(data1_box)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f65f7649b90>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f65f764eb90>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7f65f7656bd0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f65f7656690>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f65f7b4f850>,
#   <matplotlib.lines.Line2D at 0x7f65f764e650>]}

# %%
outliers = plt.boxplot(df['Ozone'])

# %%
[item.get_ydata() for item in outliers['fliers']]
# Out:
# [array([135., 168.])]

# %%
df['Weather'].value_counts().plot.bar()
import seaborn as sns

# %%
columns = df.columns 
df[columns].isnull()
# Out:
#      Unnamed: 0  Ozone  Solar.R   Wind  Temp C  Month    Day   Year   Temp  \
# 0         False  False    False  False   False  False  False  False  False
# 1         False  False    False  False   False  False  False  False  False
# 2         False  False    False  False   False  False  False  False  False
# 3         False  False    False  False   False  False  False  False  False
# 4         False   True     True  False   False  False  False  False  False
# ..          ...    ...      ...    ...     ...    ...    ...    ...    ...
# 153       False  False    False  False   False  False  False  False  False
# 154       False  False    False  False   False  False  False  False  False
# 155       False   True    False  False   False  False  False  False  False
# 156       False  False    False  False   False  False  False  False  False
# 157       False  False    False  False   False  False  False  False  False
#
#      Weather
# 0      False
# 1      False
# 2      False
# ...

# %%
df.dropna()
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 6             7   23.0    299.0   8.6     65     5    7  2010    65      PS
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 152         153   20.0    223.0  11.5     68     9   30  2010    68       S
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [113 rows x 10 columns]

# %%
df
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
sf = pd.read_csv('/content/data_clean.csv')

# %%
sf
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 0             1   41.0    190.0   7.4     67     5    1  2010    67       S
# 1             2   36.0    118.0   8.0     72     5    2  2010    72       C
# 2             3   12.0    149.0  12.6     74     5    3  2010    74      PS
# 3             4   18.0    313.0  11.5     62     5    4  2010    62       S
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# ..          ...    ...      ...   ...    ...   ...  ...   ...   ...     ...
# 153         154   41.0    190.0   7.4     67     5    1  2010    67       C
# 154         155   30.0    193.0   6.9     70     9   26  2010    70      PS
# 155         156    NaN    145.0  13.2     77     9   27  2010    77       S
# 156         157   14.0    191.0  14.3     75     9   28  2010    75       S
# 157         158   18.0    131.0   8.0     76     9   29  2010    76       C
#
# [158 rows x 10 columns]

# %%
cols = sf.columns

# %%
colors = ['#000099', '#ffff00']

# %%
sns.heatmap(sf[cols].isnull(), cmap = sns.color_palette(colors))

# %%
a = sf[sf.isnull().any(axis=1)]

# %%
a
# Out:
#      Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 4             5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5             6   28.0      NaN  14.9     66     5    6  2010    66       C
# 9            10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10           11    7.0      NaN   6.9      C     5   11  2010    74       C
# 24           25    NaN     66.0  16.6     57     5   25  2010    57      PS
# 25           26    NaN    266.0  14.9     58     5   26  2010    58       C
# 26           27    NaN      NaN   8.0     57     5   27  2010    57      PS
# 31           32    NaN    286.0   8.6     78     6    1  2010    78       S
# 32           33    NaN    287.0   9.7     74     6    2  2010    74       C
# 33           34    NaN    242.0  16.1     67     6    3  2010    67      PS
# 34           35    NaN    186.0   9.2     84     6    4  2010    84       C
# ...

# %%
a.head()
# Out:
#     Unnamed: 0  Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp Weather
# 4            5    NaN      NaN  14.3     56     5    5  2010    56       S
# 5            6   28.0      NaN  14.9     66     5    6  2010    66       C
# 9           10    NaN    194.0   8.6     69     5   10  2010    69       S
# 10          11    7.0      NaN   6.9      C     5   11  2010    74       C
# 24          25    NaN     66.0  16.6     57     5   25  2010    57      PS

# %%
sf.isnull().sum()
# Out:
# Unnamed: 0     0
# Ozone         38
# Solar.R        7
# Wind           0
# Temp C         0
# Month          0
# Day            0
# Year           0
# Temp           0
# Weather        3
# dtype: int64

# %%
me = sf['Ozone'].mean()

# %%
me
# Out:
# 41.583333333333336

# %%
sf['Ozone'] = sf['Ozone'].fillna(me)

# %%
sf
# Out:
#      Unnamed: 0      Ozone  Solar.R  Wind Temp C Month  Day  Year  Temp  \
# 0             1  41.000000    190.0   7.4     67     5    1  2010    67
# 1             2  36.000000    118.0   8.0     72     5    2  2010    72
# 2             3  12.000000    149.0  12.6     74     5    3  2010    74
# 3             4  18.000000    313.0  11.5     62     5    4  2010    62
# 4             5  41.583333      NaN  14.3     56     5    5  2010    56
# ..          ...        ...      ...   ...    ...   ...  ...   ...   ...
# 153         154  41.000000    190.0   7.4     67     5    1  2010    67
# 154         155  30.000000    193.0   6.9     70     9   26  2010    70
# 155         156  41.583333    145.0  13.2     77     9   27  2010    77
# 156         157  14.000000    191.0  14.3     75     9   28  2010    75
# 157         158  18.000000    131.0   8.0     76     9   29  2010    76
#
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# ...

# %%
sf.isnull().sum()
# Out:
# Unnamed: 0    0
# Ozone         0
# Solar.R       7
# Wind          0
# Temp C        0
# Month         0
# Day           0
# Year          0
# Temp          0
# Weather       3
# dtype: int64

# %%
obj = sf[['Weather']]

# %%
obj
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %%
obj.isnull().sum()
# Out:
# Weather    3
# dtype: int64

# %%
a = obj.mode()

# %%
a
# Out:
#   Weather
# 0       S

# %%
obj = obj.fillna(a.iloc[0])

# %%
obj
# Out:
#     Weather
# 0         S
# 1         C
# 2        PS
# 3         S
# 4         S
# ..      ...
# 153       C
# 154      PS
# 155       S
# 156       S
# 157       C
#
# [158 rows x 1 columns]

# %%
obj.isnull().sum()
# Out:
# Weather    0
# dtype: int64

# %%
newdf = pd.concat[sf,obj],axis=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-1ba7a711ed3d> in <module>()
# ----> 1 newdf = pd.concat[sf,obj],axis=1
#
# TypeError: cannot unpack non-iterable int object
