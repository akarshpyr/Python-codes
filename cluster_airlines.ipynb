# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshpyr/Python-codes/blob/main/cluster_airlines.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.cluster import hierarchy
from sklearn.cluster import AgglomerativeClustering, KMeans, DBSCAN

# %%
# !pip install xlrd
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: xlrd in /usr/local/lib/python3.7/dist-packages (1.1.0)

# %%
import xlrd

# %%
data = xlrd.open_workbook('/content/EastWestAirlines.xlsx')

# %%
data = pd.read_csv('/content/EastWestAirlines.csv')

# %%
data
# Out:
#    East-West Airlines is trying to learn more about its customers.  Key issues are their  \
# 0   flying patterns, earning and use of frequent f...
# 1   card.  The task is to identify customer segmen...
# 2                                                 NaN
# 3                                                 NaN
# 4   Source: Based upon real business data; company...
# 5              (c) 2016 Galit Shmueli and Peter Bruce
# 6                                                 NaN
# 7                                                 NaN
# 8                                          Field Name
# 9                                                 ID#
# 10                                            Balance
# 11                                         Qual_miles
# 12                                          cc1_miles
# 13                                          cc2_miles
# 14                                          cc3_miles
# 15                                 note:  miles bins:
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                        Bonus_miles
# 21                                        Bonus_trans
# 22                                  Flight_miles_12mo
# 23                                    Flight_trans_12
# 24                                  Days_since_enroll
# 25                                             Award?
#
#    Unnamed: 1       Unnamed: 2                         Unnamed: 3  \
# 0         NaN              NaN                                NaN
# 1         NaN              NaN                                NaN
# 2         NaN              NaN                                NaN
# 3         NaN              NaN                                NaN
# 4         NaN              NaN                                NaN
# 5         NaN              NaN                                NaN
# 6         NaN              NaN                                NaN
# 7         NaN              NaN                                NaN
# 8   Data Type  Max Data Length  Raw Data or Telcom Created Field?
# 9      NUMBER              NaN                             Telcom
# 10     NUMBER                8                                Raw
# 11     NUMBER                8                                Raw
# 12       CHAR                1                                Raw
# 13       CHAR                1                                Raw
# 14       CHAR                1                                Raw
# 15        NaN              NaN                                NaN
# 16        NaN              NaN                                NaN
# 17        NaN              NaN                                NaN
# 18        NaN              NaN                                NaN
# 19        NaN              NaN                                NaN
# 20     NUMBER              NaN                                Raw
# 21     NUMBER              NaN                                Raw
# 22     NUMBER              NaN                                Raw
# 23     NUMBER              NaN                                Raw
# 24     NUMBER              NaN                             Telcom
# 25     NUMBER              NaN                             Telcom
#
#                                            Unnamed: 4
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                         Description
# 9                                           Unique ID
# 10          Number of miles eligible for award travel
# 11  Number of miles counted as qualifying for Topf...
# 12  Number of miles earned with freq. flyer credit...
# 13  Number of miles earned with Rewards credit car...
# 14  Number of miles earned with Small Business cre...
# 15                                    1 = under 5,000
# 16                                 2 = 5,000 - 10,000
# 17                                3 = 10,001 - 25,000
# 18                                4 = 25,001 - 50,000
# 19                                    5 = over 50,000
# 20  Number of miles earned from non-flight bonus t...
# 21  Number of non-flight bonus transactions in the...
# 22       Number of flight miles in the past 12 months
# 23  Number of flight transactions in the past 12 m...
# 24                   Number of days since Enroll_date
# 25  Dummy variable for Last_award (1=not null, 0=n...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column                                                                                 Non-Null Count  Dtype
# ---  ------                                                                                 --------------  -----
#  0   East-West Airlines is trying to learn more about its customers.  Key issues are their  18 non-null     object
#  1   Unnamed: 1                                                                             13 non-null     object
#  2   Unnamed: 2                                                                             6 non-null      object
#  3   Unnamed: 3                                                                             13 non-null     object
#  4   Unnamed: 4                                                                             18 non-null     object
# dtypes: object(5)
# memory usage: 1.1+ KB

# %%
data = pd.read_excel('/content/EastWestAirlines.xlsx', sheet_name='data')

# %%
data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?
# 0          0
# 1          0
# 2          0
# 3          0
# 4          1
# ...      ...
# 3994       1
# 3995       1
# 3996       1
# 3997       0
# 3998       0
#
# [3999 rows x 12 columns]

# %%
from sklearn.preprocessing import normalize

# %%
air_data = data

# %%
air_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
air_df = air_data.drop('ID#',axis=1)

# %%
air_df_norm = normalize(air_df)

# %%
air_df_norm
# Out:
# array([[9.70414393e-01, 0.00000000e+00, 3.44815547e-05, ...,
#         0.00000000e+00, 2.41370883e-01, 0.00000000e+00],
#        [9.40208573e-01, 0.00000000e+00, 4.88572320e-05, ...,
#         0.00000000e+00, 3.40437193e-01, 0.00000000e+00],
#        [9.81113099e-01, 0.00000000e+00, 2.37247449e-05, ...,
#         0.00000000e+00, 1.66879855e-01, 0.00000000e+00],
#        ...,
#        [9.44947533e-01, 0.00000000e+00, 3.85184532e-05, ...,
#         0.00000000e+00, 1.80009571e-02, 1.28394844e-05],
#        [9.99591676e-01, 0.00000000e+00, 1.82078303e-05, ...,
#         1.82078303e-05, 2.55091703e-02, 0.00000000e+00],
#        [9.07271293e-01, 0.00000000e+00, 3.00819394e-04, ...,
#         0.00000000e+00, 4.20545513e-01, 0.00000000e+00]])

# %%
df = pd.DataFrame(air_df_norm, columns = air_df.columns)

# %%
df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.970414         0.0   0.000034   0.000034   0.000034     0.006000
# 1     0.940209         0.0   0.000049   0.000049   0.000049     0.010504
# 2     0.981113         0.0   0.000024   0.000024   0.000024     0.097817
# 3     0.904428         0.0   0.000061   0.000061   0.000061     0.030605
# 4     0.912226         0.0   0.000037   0.000009   0.000009     0.404078
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.905810         0.0   0.000049   0.000049   0.000049     0.417949
# 3995  0.999649         0.0   0.000016   0.000016   0.000016     0.015231
# 3996  0.944948         0.0   0.000039   0.000013   0.000013     0.326726
# 3997  0.999592         0.0   0.000018   0.000018   0.000018     0.009104
# 3998  0.907271         0.0   0.000301   0.000301   0.000301     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0        0.000034           0.000000         0.000000           0.241371
# 1        0.000098           0.000000         0.000000           0.340437
# 2        0.000095           0.000000         0.000000           0.166880
# 3        0.000061           0.000000         0.000000           0.425527
# 4        0.000243           0.019383         0.000037           0.064718
# ...           ...                ...              ...                ...
# 3994     0.000196           0.009805         0.000049           0.068784
# 3995     0.000078           0.000000         0.000000           0.021659
# 3996     0.000103           0.000000         0.000000           0.018001
# 3997     0.000018           0.009104         0.000018           0.025509
# 3998     0.000000           0.000000         0.000000           0.420546
#
#         Award?
# 0     0.000000
# 1     0.000000
# 2     0.000000
# 3     0.000000
# 4     0.000009
# ...        ...
# 3994  0.000049
# 3995  0.000016
# 3996  0.000013
# 3997  0.000000
# 3998  0.000000
#
# [3999 rows x 11 columns]

# %%
plt.figure(figsize=(10,8))
dendrogram = hierarchy.dendrogram(hierarchy.linkage(df, 'complete'))

# %%
hc = AgglomerativeClustering(n_clusters=6, affinity='euclidean',linkage='ward')

# %%
hclabel = hc.fit_predict(df)

# %%
hc.labels_
# Out:
# array([1, 2, 2, ..., 2, 1, 2])

# %%
hclabel = pd.Series(hclabel)

# %%
air_data['hclabel'] = hclabel

# %%
air_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?  hclabel
# 0          0        1
# 1          0        2
# 2          0        2
# 3          0        2
# 4          1        3
# ...      ...      ...
# 3994       1        3
# 3995       1        1
# 3996       1        2
# 3997       0        1
# 3998       0        2
#
# [3999 rows x 13 columns]

# %%
air_data.groupby('hclabel').mean()
# Out:
#                  ID#       Balance  Qual_miles  cc1_miles  cc2_miles  \
# hclabel
# 0        1950.567329  31066.514349  111.415011   3.200883   1.026490
# 1        2222.257767  94957.590260  215.220823   1.141058   1.005038
# 2        1926.244990  81201.080802  136.521008   2.115061   1.013575
# 3        2035.034542  69569.894646   97.257340   3.326425   1.032815
# 4        1578.120690   6872.149425   11.522989   1.000000   1.000000
# 5        1712.145455   1259.872727    0.000000   1.000000   1.000000
#
#          cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# hclabel
# 0         1.070640  40266.935982    17.289183         626.754967
# 1         1.002519   3524.928631     5.640638         461.104954
# 2         1.000646  16350.149968    13.574014         488.550743
# 3         1.022453  35743.675302    17.784111         406.804836
# 4         1.000000    603.034483     2.385057          71.201149
# 5         1.000000    526.000000     2.454545          53.636364
#
#          Flight_trans_12  Days_since_enroll    Award?
# hclabel
# 0               1.812362        4205.624724  0.858720
# 1               1.521411        3736.071369  0.230898
# 2               1.340659        4285.891403  0.312217
# 3               1.274611        4090.832470  0.525043
# 4               0.212644        4929.948276  0.126437
# 5               0.200000        4702.418182  0.145455

# %%
plt.scatter(air_data.hclabel, air_data.Balance, c = hc.labels_)
plt.xlabel('cluster_id')
plt.ylabel('balance')
plt.show()

# %%
wcss = []
for i in range(1,11):
  kmeans = KMeans(n_clusters=i)
  kmeans.fit(df)
  wcss.append(kmeans.inertia_)
plt.plot(range(1,11),wcss)
plt.title('elbow_curve')
plt.xlabel('K-value')
plt.ylabel('WCSS')
plt.show()

# %%
model = KMeans(n_clusters=4,init='k-means++',random_state=34)

# %%
clusters = model.fit_predict(df)

# %%
clusters
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int32)

# %%
air_data['y_kmeans'] = clusters

# %%
df0 = air_data[air_data.y_kmeans ==0]
df1 = air_data[air_data.y_kmeans ==1]
df2 = air_data[air_data.y_kmeans ==2]
df3 = air_data[air_data.y_kmeans ==3]

# %%
plt.scatter(df0['Balance'],df0['Award?'],color='red',label = 'c1')
plt.scatter(df1['Balance'],df1['Award?'],color='blue',label = 'c2')
plt.scatter(df2['Balance'],df2['Award?'],color='green',label = 'c3')
plt.scatter(df3['Balance'],df3['Award?'],color='yellow',label = 'c4')
plt.ylabel('Award?')
plt.xlabel('Balance')
plt.legend()
plt.show()

# %%
plt.scatter(df0['Balance'],df0['Bonus_miles'],color='red',label = 'c1')
plt.scatter(df1['Balance'],df1['Bonus_miles'],color='blue',label = 'c2')
plt.scatter(df2['Balance'],df2['Bonus_miles'],color='green',label = 'c3')
plt.scatter(df3['Balance'],df3['Bonus_miles'],color='yellow',label = 'c4')
plt.ylabel('Bonus_miles')
plt.xlabel('Balance')
plt.legend()
plt.show()
plt.figure(figsize=(16,10))

# %%
air_data.shape
# Out:
# (3999, 14)

# %%
dbscan = DBSCAN(eps=1, min_samples=12)

# %%
y_dbscan = dbscan.fit_predict(df)

# %%
y_dbscan
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_dbscan = pd.Series(y_dbscan)

# %%
air_data['DBscan'] = y_dbscan

# %%
air_data
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# 0               1                  0                0               7000
# 1               2                  0                0               6968
# 2               4                  0                0               7034
# 3               1                  0                0               6952
# 4              26               2077                4               6935
# ...           ...                ...              ...                ...
# 3994            4                200                1               1403
# 3995            5                  0                0               1395
# 3996            8                  0                0               1402
# 3997            1                500                1               1401
# 3998            0                  0                0               1398
#
#       Award?  hclabel  y_kmeans  DBscan
# 0          0        1         0       0
# 1          0        2         0       0
# 2          0        2         0       0
# 3          0        2         0       0
# 4          1        3         1       0
# ...      ...      ...       ...     ...
# 3994       1        3         1       0
# 3995       1        1         0       0
# 3996       1        2         1       0
# 3997       0        1         0       0
# 3998       0        2         0       0
#
# [3999 rows x 15 columns]

# %%
air_data['DBscan'].value_counts()
# Out:
# 0    3999
# Name: DBscan, dtype: int64
