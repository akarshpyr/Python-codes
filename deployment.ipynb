# %% [markdown]
# <a href="https://colab.research.google.com/github/akarshpyr/Python-codes/blob/main/deployment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install streamlit
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 9.1 MB 6.0 MB/s
# ...
#      |████████████████████████████████| 4.3 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 181 kB 69.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 7.1 MB/s
# ...
#      |████████████████████████████████| 111 kB 58.4 MB/s
# ...
#      |████████████████████████████████| 164 kB 55.6 MB/s
# ...
#      |████████████████████████████████| 232 kB 55.0 MB/s
# ...
#      |████████████████████████████████| 63 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 133 kB 66.2 MB/s
# ...
#      |████████████████████████████████| 132 kB 72.5 MB/s
# ...
#      |████████████████████████████████| 428 kB 57.9 MB/s
# ...
#      |████████████████████████████████| 793 kB 52.2 MB/s
# ...
#      |████████████████████████████████| 381 kB 50.6 MB/s
# ...
#      |████████████████████████████████| 51 kB 6.5 MB/s
# ...

# %%
import pandas as pd
import streamlit as st
from sklearn.linear_model import LogisticRegression

# %%
st.title('Model Deployment: Logistic Regression')
st.sidebar.header('User input parameters')
def user_input_features():
  CLMSEX = st.sidebar.selectbox('Gender',('1','0'))
  CLMINSUR = st.sidebar.selectbox('Insurance',('1','0'))
  SEATBELT = st.sidebar.selectbox('Seatbelt',('1','0'))
  CLMAGE = st.sidebar.number_input('Insert the age')
  LOSS = st.sidebar.number_input('Insert loss')
  data = { 'CLMSEX': CLMSEX,
  "CLMINSUR":CLMINSUR,
   "SEATBELT" :SEATBELT,
  "CLMAGE" : CLMAGE,
  "LOSS" : LOSS}
  features = pd.DataFrame(data, index=[0])
  return features
# Out:
# 2022-06-23 11:22:21.396
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
df = user_input_features()
st.subheader('User input parameters')
st.write(df)

# %%
claimants = pd.read_csv('/content/claimants.csv')
claimants.drop(['CASENUM'],inplace=True,axis=1)
claimants= claimants.dropna()

# %%
claimants
# Out:
#       ATTORNEY  CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0            0     0.0       1.0       0.0    50.0  34.940
# 1            1     1.0       0.0       0.0    18.0   0.891
# 2            1     0.0       1.0       0.0     5.0   0.330
# 3            0     0.0       1.0       1.0    31.0   0.037
# 4            1     0.0       1.0       0.0    30.0   0.038
# ...        ...     ...       ...       ...     ...     ...
# 1334         1     1.0       1.0       0.0    16.0   0.060
# 1336         0     1.0       1.0       0.0    46.0   3.705
# 1337         1     1.0       1.0       0.0    39.0   0.099
# 1338         0     1.0       0.0       0.0     8.0   3.177
# 1339         1     1.0       1.0       0.0    30.0   0.688
#
# [1096 rows x 6 columns]

# %%
X = claimants.iloc[:,[1,2,3,4,5]]

# %%
X
# Out:
#       CLMSEX  CLMINSUR  SEATBELT  CLMAGE    LOSS
# 0        0.0       1.0       0.0    50.0  34.940
# 1        1.0       0.0       0.0    18.0   0.891
# 2        0.0       1.0       0.0     5.0   0.330
# 3        0.0       1.0       1.0    31.0   0.037
# 4        0.0       1.0       0.0    30.0   0.038
# ...      ...       ...       ...     ...     ...
# 1334     1.0       1.0       0.0    16.0   0.060
# 1336     1.0       1.0       0.0    46.0   3.705
# 1337     1.0       1.0       0.0    39.0   0.099
# 1338     1.0       0.0       0.0     8.0   3.177
# 1339     1.0       1.0       0.0    30.0   0.688
#
# [1096 rows x 5 columns]

# %%
Y = claimants.iloc[:,0]

# %%
Y
# Out:
# 0       0
# 1       1
# 2       1
# 3       0
# 4       1
#        ..
# 1334    1
# 1336    0
# 1337    1
# 1338    0
# 1339    1
# Name: ATTORNEY, Length: 1096, dtype: int64

# %%
clf = LogisticRegression()
clf.fit(X,Y)
# Out:
# LogisticRegression()

# %%
prediction = clf.predict(df)
prediction_probab = clf.predict_proba(df)

# %%
st.subheader('Predicted result')
st.write('Yes' if prediction_probab[0][1]>0.5 else 'No')
st.subheader('Prediction probablity')
st.write(prediction_probab)
